# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import joblib
import matplotlib.pyplot as plt
# Out:
# Mounted at /content/drive

# %%
model = joblib.load(
    "/content/drive/MyDrive/AI_ML_Projects 2026/Models/Student_Performance_Prediction/student_performance_model.pkl"
)

print("Model Loaded Successfully!")
# Out:
# Model Loaded Successfully!

# %%
features = [
    "Study_Hours",
    "Attendance",
    "Assignments",
    "Quiz_Score"
]

# %%
coefficients = model.coef_

importance = pd.DataFrame({
    "Feature": features,
    "Coefficient": coefficients
})

importance
# Out:
#        Feature  Coefficient
# 0  Study_Hours     3.956754
# 1   Attendance     0.265826
# 2  Assignments     1.977502
# 3   Quiz_Score     0.345561

# %%
importance = importance.sort_values(
    by="Coefficient",
    ascending=False
)

importance
# Out:
#        Feature  Coefficient
# 0  Study_Hours     3.956754
# 2  Assignments     1.977502
# 3   Quiz_Score     0.345561
# 1   Attendance     0.265826

# %%
plt.figure(figsize=(8,5))

bars = plt.bar(
    importance["Feature"],
    importance["Coefficient"]
)

plt.title("Feature Importance - Linear Regression")
plt.xlabel("Features")
plt.ylabel("Coefficient")

for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f"{height:.2f}",
        ha="center",
        va="bottom"
    )

plt.show()

# %%
print("Feature Importance:\n")

for i, row in importance.iterrows():
    print(
        f"{row['Feature']} : {round(row['Coefficient'],2)}"
    )
# Out:
# Feature Importance:
#
# Study_Hours : 3.96
# Assignments : 1.98
# Quiz_Score : 0.35
# Attendance : 0.27
